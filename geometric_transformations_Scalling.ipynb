# %%
import cv2
from matplotlib import pyplot as plt
from google.colab import drive
drive.mount('/content/drive')
image_path = '/content/drive/MyDrive/computervision/data/image.png'
image = cv2.imread(image_path)
# Display the image
plt.imshow(image)

# %%
scalling_image= cv2.resize(image,None,fx=0.5,fy=0.5, interpolation=cv2.INTER_CUBIC)
plt.imshow(scalling_image)

# %%
print(scalling_image.shape)
print(image.shape)
